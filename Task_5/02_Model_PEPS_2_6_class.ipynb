# %% [markdown]
# #  Model PEPS
# The notebook below shows the variational circuit. We present a binary classifier based on articles:
#
# * ["Supervised Learning with Projected Entangled Pair States" discusses the application of projected entangled pair states (PEPS)"](https://arxiv.org/abs/2009.09932)
# * [A practical introduction to tensor networks: Matrix product states and projected entangled pair states](https://www.sciencedirect.com/science/article/pii/S0003491614001596)
#
# We're utilizing PCA for dimensionality reduction. We also conducted experiments for a 6-class classification task, adjusting the metrics accordingly. In the future, it would be beneficial to further explore this architecture by tuning hyperparameters, experimenting with different cost functions, and considering alternative dimensionality reduction techniques.
#
# We initially used only the `cross-entropy` cost function, but the code is designed to easily switch to other cost functions, such as the `average exponential` cost function or the `average focal` cost function, both of which are available in the 'training.py' file.
#
# <a id="0"></a> <br>
# 1. [Data Preparation](#1)
# 2. [Model](#2)
# 3. [Experiment 1 - 2 classes](#3)
# 4. [Experiment 2 - 2 classes](#4)
#
# Parameters:
# * corpping - `vertical_start_split=0.3, vertical_end_split=1.0,horizontal_start_split=0.25, horizontal_end_split=0.75`
# * image size to resize - `(64, 64)`
# * PCA components - `256`
# * Split data to train and validation - `train_ratio=0.8`
# * cost functino - cross entropy
#
#
#
# | Experiment | Class | Training set         | Validation set       | Test set             | Cost function      | Epoch | Batch | Learning rate | Training time | Val_accuracy | Test_accuracy |
# |------------|-----| ------------------|----------------------|----------------------|--------------------|-------|-------|----------------|---------------|--------------|---------------|
# | 1     | 2     | [138 141] | [20 21]  | [42 38] | Cross-Entropy Loss | 200    | 64    | 0.1           | 0.5 h         | 92.68%        | 76%           |
# | 2     | 2   | [138 141] | [20 21]  | [42 38] | Cross-Entropy Loss | 300   | 128   | 0.1           | 1 h           | 85.37%       | 80%         |
# | -     | 6    | [331 331 315 310 320 317] | - | [70 70 86 91 81 84] | Cross-Entropy Loss | 50   | -    | 0.1           | 2 h         | -          | 47.51%        |
# | -     | 6    | [78 78 88 81 78 81] | - | [23 23 13 20 23 20] | Cross-Entropy Loss | 50   | -    | 0.1           |  -       | -         | 63.11%        |
#
# For the experiments we calculate also another metrics:Precision,Recall,F1 Score,Balanced Accuracy, AUC-ROC, confusion matrix.

# %% [markdown]
# Experiments for the 6-class classification are not included here; we only provide a summary of the results.

# %% [markdown]
# <a id="1"></a> <br>
# ### Data Preparation

# %% [markdown]
# Initialize the ImageLoader to load and preprocess data.
# Below, we load up to 100 images per label, applies cropping with specified parameters to focus on relevant image regions, and resizes each image to 64x64 pixels for consistency.
#
# Cropping parameters: `vertical_start_split=0.3, vertical_end_split=1.0,horizontal_start_split=0.25, horizontal_end_split=0.75`.
# Image size to resize: `(64, 64)`

# %%
from Modules.ImageLoader import ImageLoader
loader = ImageLoader(['./Data_Sources/al5083/train'], ['./Data_Sources/al5083/train/train.json'], (64, 64))
all_data = loader.load_images(image_limit=200,vertical_start_split=0.3, vertical_end_split=1.0,
                              horizontal_start_split=0.25, horizontal_end_split=0.75)
# Out:
# Images loaded: 1200, Current label: 5, Total per label: {0: 200, 1: 200, 2: 200, 3: 200, 4: 200, 5: 200}
#
# Total images loaded : 1200
# Label count : {0: 200, 1: 200, 2: 200, 3: 200, 4: 200, 5: 200}

# %% [markdown]
# Create a balanced dataset for binary classification, where Class 1 consists of five different types of defective images.

# %%
from Modules.Utils import reduce_dataset_to_2_classes
binary_all_data = reduce_dataset_to_2_classes(all_data, class_0_count=200, other_classes_count=40)

# %% [markdown]
# Shuffles the dataset, flattens the image data arrays, scales the flattened features, and separates them into features and labels. Applies PCA to reduce the dimensionality of the given dataset to components = `256`

# %%
from  Modules.Utils import prepare_data
from Modules.Utils import apply_pca

X_set,Y_set = prepare_data(binary_all_data)
X_reduced = apply_pca(X_set, n_components=256)

# %% [markdown]
# Split train data to train set and validation set. `train_ratio=0.8`

# %%
from Modules.Utils import split_data_into_train_val_test

X_train, Y_train, X_val, Y_val, X_test, Y_test = split_data_into_train_val_test(X = X_reduced, Y = Y_set, train_ratio=0.7, val_ratio=0.1,test_ratio=0.2)
# Out:
# Y_train: Values: [0 1] Counts: [138 141]
# Y_val: Values: [0 1] Counts: [20 21]
# Y_test: Values: [0 1] Counts: [42 38]

# %% [markdown]
# <a id="2"></a> <br>
# ### Model
# While developing the model, we used:
# * ["Supervised Learning with Projected Entangled Pair States"](https://arxiv.org/abs/2009.09932) discusses the application of projected entangled pair states (PEPS) in constructing supervised learning models, particularly for image data.
# * [A practical introduction to tensor networks: Matrix product states and projected entangled pair states](https://www.sciencedirect.com/science/article/pii/S0003491614001596)

# %%
import pennylane as qml
from pennylane import numpy as np
dev = qml.device("default.qubit", wires=8)

@qml.qnode(dev)
def circuit_peps(image, template_weights):
    qml.AmplitudeEmbedding(features=image, wires=range(8), normalize=True)

    i = 0

    qml.RY(template_weights[i], wires=3)
    i = i+1
    qml.RY(template_weights[i], wires=4)
    i = i+1
    qml.CNOT(wires=[3, 4])

    qml.RY(template_weights[i], wires=2)
    i = i+1
    qml.RY(template_weights[i], wires=3)
    i = i+1
    qml.CNOT(wires=[2, 3])

    qml.RY(template_weights[i], wires=4)
    i = i+1
    qml.RY(template_weights[i], wires=5)
    i = i+1
    qml.CNOT(wires=[4, 5])

    for j in range(1, 6, 2):
        qml.RY(template_weights[i], wires=j)
        i = i+1
        qml.RY(template_weights[i], wires=j+1)
        i = i+1
        qml.CNOT(wires=[j, j+1])

    for j in range(0, 7, 2):
        qml.RY(template_weights[i], wires=j)
        i = i+1
        qml.RY(template_weights[i], wires=j+1)
        i = i+1
        qml.CNOT(wires=[j, j+1])

    for j in range(1, 6, 2):
        qml.RY(template_weights[i], wires=j)
        i = i+1
        qml.RY(template_weights[i], wires=j+1)
        i = i+1
        qml.CNOT(wires=[j, j+1])

    qml.RY(template_weights[i], wires=2)
    i = i+1
    qml.RY(template_weights[i], wires=3)
    i = i+1
    qml.CNOT(wires=[2, 3])

    qml.RY(template_weights[i], wires=4)
    i = i+1
    qml.RY(template_weights[i], wires=5)
    i = i+1
    qml.CNOT(wires=[4, 5])

    qml.RY(template_weights[i], wires=3)
    i = i+1
    qml.RY(template_weights[i], wires=4)
    i = i+1
    qml.CNOT(wires=[3, 4])

    return qml.probs(wires = [4])

weights = np.random.random(size=[32, 1])
qml.draw_mpl(circuit_peps, expansion_strategy="device")(X_train[0], weights)
circuit_peps(X_train[0], weights)
# Out:
# tensor([[0.54971074, 0.45028926]], requires_grad=True)

# %% [markdown]
# <a id="3"></a> <br>
# ### Experiment 1 - 2 classes
# In this section, we perform the training process of the above model. Below, we see the cross entropy cost function. We use the following hyperparameters for training:
# * `qml.AdamOptimizer(stepsize=0.1)`
# * `batch_size = 64`
# * `num_epoch = 300`

# %%
# training the circuit parameters
from pennylane import numpy as np
params = np.random.random(size=[32, 1], requires_grad=True)
optimizer = qml.AdamOptimizer(stepsize=0.1)
batch_size = 64
num_epoch = 300

# %%
from Modules.training import train_model
import time

start_time = time.time()
all_params, train_accuracies, val_accuracies, costs = train_model(X_train, Y_train, X_val, Y_val, params, optimizer, circuit_peps, 2, num_epoch, batch_size)
print("--- %hr --- %", (time.time() - start_time)/3600)
# Out:
# Epoch: 1 | Cost: 0.6502614 | Acc train: 0.6875000 | Acc validation: 0.4878049
# Epoch: 2 | Cost: 0.6146321 | Acc train: 0.6562500 | Acc validation: 0.4878049
# Epoch: 3 | Cost: 0.6100793 | Acc train: 0.6718750 | Acc validation: 0.5365854
# Epoch: 4 | Cost: 0.6552310 | Acc train: 0.6406250 | Acc validation: 0.4878049
# Epoch: 5 | Cost: 0.6345756 | Acc train: 0.6406250 | Acc validation: 0.5121951
# Epoch: 6 | Cost: 0.6142550 | Acc train: 0.7812500 | Acc validation: 0.5121951
# Epoch: 7 | Cost: 0.6486786 | Acc train: 0.6562500 | Acc validation: 0.5609756
# Epoch: 8 | Cost: 0.6345118 | Acc train: 0.6875000 | Acc validation: 0.5853659
# Epoch: 9 | Cost: 0.6262589 | Acc train: 0.6875000 | Acc validation: 0.5853659
# Epoch: 10 | Cost: 0.6259838 | Acc train: 0.6562500 | Acc validation: 0.6341463
# Epoch: 11 | Cost: 0.6437239 | Acc train: 0.6718750 | Acc validation: 0.6341463
# Epoch: 12 | Cost: 0.5867757 | Acc train: 0.7031250 | Acc validation: 0.6585366
# Epoch: 13 | Cost: 0.6231945 | Acc train: 0.7343750 | Acc validation: 0.6829268
# Epoch: 14 | Cost: 0.6073030 | Acc train: 0.7187500 | Acc validation: 0.6829268
# Epoch: 15 | Cost: 0.6024620 | Acc train: 0.7812500 | Acc validation: 0.6097561
# Epoch: 16 | Cost: 0.6074015 | Acc train: 0.7656250 | Acc validation: 0.6341463
# Epoch: 17 | Cost: 0.6262419 | Acc train: 0.6562500 | Acc validation: 0.6097561
# Epoch: 18 | Cost: 0.6151547 | Acc train: 0.7500000 | Acc validation: 0.6097561
# Epoch: 19 | Cost: 0.6238935 | Acc train: 0.6718750 | Acc validation: 0.6097561
# Epoch: 20 | Cost: 0.5929429 | Acc train: 0.7187500 | Acc validation: 0.5609756
# Epoch: 21 | Cost: 0.6418787 | Acc train: 0.6562500 | Acc validation: 0.5853659
# Epoch: 22 | Cost: 0.6205404 | Acc train: 0.7343750 | Acc validation: 0.5853659
# Epoch: 23 | Cost: 0.6318998 | Acc train: 0.6718750 | Acc validation: 0.5853659
# Epoch: 24 | Cost: 0.6417997 | Acc train: 0.6406250 | Acc validation: 0.5609756
# Epoch: 25 | Cost: 0.6523402 | Acc train: 0.6406250 | Acc validation: 0.5609756
# Epoch: 26 | Cost: 0.6252221 | Acc train: 0.7343750 | Acc validation: 0.6097561
# Epoch: 27 | Cost: 0.6620813 | Acc train: 0.6718750 | Acc validation: 0.6585366
# Epoch: 28 | Cost: 0.5891824 | Acc train: 0.7656250 | Acc validation: 0.6585366
# Epoch: 29 | Cost: 0.6113460 | Acc train: 0.6875000 | Acc validation: 0.6341463
# Epoch: 30 | Cost: 0.5395713 | Acc train: 0.8281250 | Acc validation: 0.6341463
# Epoch: 31 | Cost: 0.5738342 | Acc train: 0.7500000 | Acc validation: 0.6585366
# Epoch: 32 | Cost: 0.5664150 | Acc train: 0.6718750 | Acc validation: 0.7073171
# Epoch: 33 | Cost: 0.6208603 | Acc train: 0.6250000 | Acc validation: 0.7073171
# Epoch: 34 | Cost: 0.5321402 | Acc train: 0.7343750 | Acc validation: 0.7073171
# Epoch: 35 | Cost: 0.6166288 | Acc train: 0.6718750 | Acc validation: 0.7073171
# Epoch: 36 | Cost: 0.5228127 | Acc train: 0.7500000 | Acc validation: 0.6829268
# Epoch: 37 | Cost: 0.6271429 | Acc train: 0.6406250 | Acc validation: 0.6341463
# Epoch: 38 | Cost: 0.5726004 | Acc train: 0.7500000 | Acc validation: 0.6097561
# Epoch: 39 | Cost: 0.5903565 | Acc train: 0.7187500 | Acc validation: 0.6585366
# Epoch: 40 | Cost: 0.5552541 | Acc train: 0.7656250 | Acc validation: 0.5853659
# Epoch: 41 | Cost: 0.6095467 | Acc train: 0.6406250 | Acc validation: 0.5609756
# Epoch: 42 | Cost: 0.6631750 | Acc train: 0.5312500 | Acc validation: 0.5609756
# Epoch: 43 | Cost: 0.5938428 | Acc train: 0.6718750 | Acc validation: 0.5609756
# Epoch: 44 | Cost: 0.6428077 | Acc train: 0.6093750 | Acc validation: 0.5365854
# Epoch: 45 | Cost: 0.5803918 | Acc train: 0.7031250 | Acc validation: 0.5853659
# Epoch: 46 | Cost: 0.5575295 | Acc train: 0.7500000 | Acc validation: 0.6097561
# Epoch: 47 | Cost: 0.6037616 | Acc train: 0.7187500 | Acc validation: 0.6341463
# Epoch: 48 | Cost: 0.5721465 | Acc train: 0.7500000 | Acc validation: 0.6585366
# Epoch: 49 | Cost: 0.5665710 | Acc train: 0.7343750 | Acc validation: 0.6585366
# Epoch: 50 | Cost: 0.5962413 | Acc train: 0.6875000 | Acc validation: 0.6829268
# Epoch: 51 | Cost: 0.5994326 | Acc train: 0.6718750 | Acc validation: 0.7073171
# Epoch: 52 | Cost: 0.5734167 | Acc train: 0.6875000 | Acc validation: 0.6829268
# Epoch: 53 | Cost: 0.5404210 | Acc train: 0.7812500 | Acc validation: 0.7073171
# Epoch: 54 | Cost: 0.5294068 | Acc train: 0.7500000 | Acc validation: 0.7317073
# Epoch: 55 | Cost: 0.5556848 | Acc train: 0.7343750 | Acc validation: 0.7317073
# Epoch: 56 | Cost: 0.5347005 | Acc train: 0.8125000 | Acc validation: 0.7560976
# Epoch: 57 | Cost: 0.6016718 | Acc train: 0.6875000 | Acc validation: 0.7317073
# Epoch: 58 | Cost: 0.4792031 | Acc train: 0.8437500 | Acc validation: 0.7317073
# Epoch: 59 | Cost: 0.5475363 | Acc train: 0.7656250 | Acc validation: 0.7317073
# Epoch: 60 | Cost: 0.5541622 | Acc train: 0.7968750 | Acc validation: 0.7560976
# Epoch: 61 | Cost: 0.5290170 | Acc train: 0.7968750 | Acc validation: 0.7560976
# Epoch: 62 | Cost: 0.5988028 | Acc train: 0.6562500 | Acc validation: 0.7073171
# Epoch: 63 | Cost: 0.5203309 | Acc train: 0.8125000 | Acc validation: 0.6585366
# Epoch: 64 | Cost: 0.5507365 | Acc train: 0.7656250 | Acc validation: 0.6585366
# Epoch: 65 | Cost: 0.5503976 | Acc train: 0.7343750 | Acc validation: 0.6585366
# Epoch: 66 | Cost: 0.5453005 | Acc train: 0.7343750 | Acc validation: 0.6829268
# Epoch: 67 | Cost: 0.5235970 | Acc train: 0.7656250 | Acc validation: 0.6829268
# Epoch: 68 | Cost: 0.5444221 | Acc train: 0.7812500 | Acc validation: 0.7317073
# Epoch: 69 | Cost: 0.5272229 | Acc train: 0.7656250 | Acc validation: 0.7317073
# Epoch: 70 | Cost: 0.5261653 | Acc train: 0.8125000 | Acc validation: 0.7073171
# Epoch: 71 | Cost: 0.5866097 | Acc train: 0.7500000 | Acc validation: 0.7317073
# Epoch: 72 | Cost: 0.5816516 | Acc train: 0.7343750 | Acc validation: 0.7560976
# Epoch: 73 | Cost: 0.5709097 | Acc train: 0.7812500 | Acc validation: 0.7560976
# Epoch: 74 | Cost: 0.5286451 | Acc train: 0.7812500 | Acc validation: 0.6829268
# Epoch: 75 | Cost: 0.5659413 | Acc train: 0.7031250 | Acc validation: 0.7073171
# Epoch: 76 | Cost: 0.5181984 | Acc train: 0.7812500 | Acc validation: 0.6585366
# Epoch: 77 | Cost: 0.5790897 | Acc train: 0.7031250 | Acc validation: 0.6829268
# Epoch: 78 | Cost: 0.5491383 | Acc train: 0.7656250 | Acc validation: 0.6097561
# Epoch: 79 | Cost: 0.5932695 | Acc train: 0.7343750 | Acc validation: 0.6097561
# Epoch: 80 | Cost: 0.6040676 | Acc train: 0.7031250 | Acc validation: 0.6097561
# Epoch: 81 | Cost: 0.5782680 | Acc train: 0.6562500 | Acc validation: 0.6829268
# Epoch: 82 | Cost: 0.6135047 | Acc train: 0.6562500 | Acc validation: 0.7073171
# Epoch: 83 | Cost: 0.5374301 | Acc train: 0.8125000 | Acc validation: 0.7073171
# Epoch: 84 | Cost: 0.5380897 | Acc train: 0.7500000 | Acc validation: 0.7804878
# Epoch: 85 | Cost: 0.5860243 | Acc train: 0.7031250 | Acc validation: 0.7804878
# Epoch: 86 | Cost: 0.5664209 | Acc train: 0.7187500 | Acc validation: 0.7560976
# Epoch: 87 | Cost: 0.5687895 | Acc train: 0.7656250 | Acc validation: 0.7560976
# Epoch: 88 | Cost: 0.5588394 | Acc train: 0.7343750 | Acc validation: 0.7804878
# Epoch: 89 | Cost: 0.4869144 | Acc train: 0.9062500 | Acc validation: 0.8292683
# Epoch: 90 | Cost: 0.5122611 | Acc train: 0.7812500 | Acc validation: 0.8292683
# Epoch: 91 | Cost: 0.5288386 | Acc train: 0.7656250 | Acc validation: 0.7804878
# Epoch: 92 | Cost: 0.5410546 | Acc train: 0.7343750 | Acc validation: 0.7804878
# Epoch: 93 | Cost: 0.5791046 | Acc train: 0.6718750 | Acc validation: 0.7804878
# Epoch: 94 | Cost: 0.5635088 | Acc train: 0.7500000 | Acc validation: 0.7804878
# Epoch: 95 | Cost: 0.5407639 | Acc train: 0.7343750 | Acc validation: 0.7804878
# Epoch: 96 | Cost: 0.5292937 | Acc train: 0.7968750 | Acc validation: 0.7804878
# Epoch: 97 | Cost: 0.4875952 | Acc train: 0.8437500 | Acc validation: 0.7804878
# Epoch: 98 | Cost: 0.5308590 | Acc train: 0.8437500 | Acc validation: 0.6829268
# Epoch: 99 | Cost: 0.5241564 | Acc train: 0.8281250 | Acc validation: 0.6585366
# Epoch: 100 | Cost: 0.5239636 | Acc train: 0.7968750 | Acc validation: 0.7073171
# Epoch: 101 | Cost: 0.5053092 | Acc train: 0.7968750 | Acc validation: 0.7073171
# Epoch: 102 | Cost: 0.5111697 | Acc train: 0.7812500 | Acc validation: 0.7073171
# Epoch: 103 | Cost: 0.5120819 | Acc train: 0.7500000 | Acc validation: 0.7073171
# Epoch: 104 | Cost: 0.5174906 | Acc train: 0.7812500 | Acc validation: 0.7317073
# Epoch: 105 | Cost: 0.5131119 | Acc train: 0.8281250 | Acc validation: 0.7317073
# Epoch: 106 | Cost: 0.5528713 | Acc train: 0.7656250 | Acc validation: 0.7073171
# Epoch: 107 | Cost: 0.5595967 | Acc train: 0.7343750 | Acc validation: 0.7073171
# Epoch: 108 | Cost: 0.5422207 | Acc train: 0.8281250 | Acc validation: 0.7560976
# Epoch: 109 | Cost: 0.6102842 | Acc train: 0.6875000 | Acc validation: 0.8048780
# Epoch: 110 | Cost: 0.5330443 | Acc train: 0.7656250 | Acc validation: 0.8048780
# Epoch: 111 | Cost: 0.5409144 | Acc train: 0.6875000 | Acc validation: 0.7804878
# Epoch: 112 | Cost: 0.5619380 | Acc train: 0.7187500 | Acc validation: 0.7804878
# Epoch: 113 | Cost: 0.5184094 | Acc train: 0.7500000 | Acc validation: 0.8048780
# Epoch: 114 | Cost: 0.5222901 | Acc train: 0.8281250 | Acc validation: 0.8048780
# Epoch: 115 | Cost: 0.5359592 | Acc train: 0.7968750 | Acc validation: 0.8536585
# Epoch: 116 | Cost: 0.5344017 | Acc train: 0.7656250 | Acc validation: 0.8780488
# Epoch: 117 | Cost: 0.5263097 | Acc train: 0.7500000 | Acc validation: 0.8536585
# Epoch: 118 | Cost: 0.5616529 | Acc train: 0.7968750 | Acc validation: 0.8048780
# Epoch: 119 | Cost: 0.5123987 | Acc train: 0.8437500 | Acc validation: 0.7804878
# Epoch: 120 | Cost: 0.5110206 | Acc train: 0.8281250 | Acc validation: 0.7804878
# Epoch: 121 | Cost: 0.5386268 | Acc train: 0.8437500 | Acc validation: 0.7317073
# Epoch: 122 | Cost: 0.5349600 | Acc train: 0.7812500 | Acc validation: 0.7073171
# Epoch: 123 | Cost: 0.5629307 | Acc train: 0.7031250 | Acc validation: 0.7804878
# Epoch: 124 | Cost: 0.4909186 | Acc train: 0.8593750 | Acc validation: 0.7804878
# Epoch: 125 | Cost: 0.5223207 | Acc train: 0.8125000 | Acc validation: 0.8292683
# Epoch: 126 | Cost: 0.5103991 | Acc train: 0.7968750 | Acc validation: 0.8048780
# Epoch: 127 | Cost: 0.5861236 | Acc train: 0.7031250 | Acc validation: 0.8048780
# Epoch: 128 | Cost: 0.5535899 | Acc train: 0.7656250 | Acc validation: 0.8048780
# Epoch: 129 | Cost: 0.5510983 | Acc train: 0.6875000 | Acc validation: 0.8048780
# Epoch: 130 | Cost: 0.5138379 | Acc train: 0.8281250 | Acc validation: 0.7804878
# Epoch: 131 | Cost: 0.5248172 | Acc train: 0.7812500 | Acc validation: 0.8292683
# Epoch: 132 | Cost: 0.5178395 | Acc train: 0.8281250 | Acc validation: 0.7804878
# Epoch: 133 | Cost: 0.5146620 | Acc train: 0.7812500 | Acc validation: 0.7804878
# Epoch: 134 | Cost: 0.5290183 | Acc train: 0.7812500 | Acc validation: 0.8048780
# Epoch: 135 | Cost: 0.5417049 | Acc train: 0.8281250 | Acc validation: 0.8048780
# Epoch: 136 | Cost: 0.5409638 | Acc train: 0.7500000 | Acc validation: 0.7804878
# Epoch: 137 | Cost: 0.4797309 | Acc train: 0.8593750 | Acc validation: 0.7804878
# Epoch: 138 | Cost: 0.4722083 | Acc train: 0.8750000 | Acc validation: 0.8048780
# Epoch: 139 | Cost: 0.5131706 | Acc train: 0.7812500 | Acc validation: 0.8048780
# Epoch: 140 | Cost: 0.5526762 | Acc train: 0.7500000 | Acc validation: 0.8048780
# Epoch: 141 | Cost: 0.4729343 | Acc train: 0.8750000 | Acc validation: 0.8048780
# Epoch: 142 | Cost: 0.5654104 | Acc train: 0.7500000 | Acc validation: 0.8292683
# Epoch: 143 | Cost: 0.5453840 | Acc train: 0.7812500 | Acc validation: 0.8048780
# Epoch: 144 | Cost: 0.5563470 | Acc train: 0.7343750 | Acc validation: 0.7804878
# Epoch: 145 | Cost: 0.5170110 | Acc train: 0.8906250 | Acc validation: 0.8048780
# Epoch: 146 | Cost: 0.5356003 | Acc train: 0.8281250 | Acc validation: 0.8048780
# Epoch: 147 | Cost: 0.4912698 | Acc train: 0.8593750 | Acc validation: 0.8048780
# Epoch: 148 | Cost: 0.4973712 | Acc train: 0.7968750 | Acc validation: 0.8292683
# Epoch: 149 | Cost: 0.5345174 | Acc train: 0.7656250 | Acc validation: 0.8292683
# Epoch: 150 | Cost: 0.5888056 | Acc train: 0.7343750 | Acc validation: 0.8292683
# Epoch: 151 | Cost: 0.5165589 | Acc train: 0.7656250 | Acc validation: 0.8048780
# Epoch: 152 | Cost: 0.5536243 | Acc train: 0.8281250 | Acc validation: 0.8292683
# Epoch: 153 | Cost: 0.5258131 | Acc train: 0.8125000 | Acc validation: 0.8536585
# Epoch: 154 | Cost: 0.4597628 | Acc train: 0.8906250 | Acc validation: 0.8292683
# Epoch: 155 | Cost: 0.5592336 | Acc train: 0.8281250 | Acc validation: 0.8292683
# Epoch: 156 | Cost: 0.5260889 | Acc train: 0.8281250 | Acc validation: 0.8048780
# Epoch: 157 | Cost: 0.5405323 | Acc train: 0.7968750 | Acc validation: 0.7560976
# Epoch: 158 | Cost: 0.5047242 | Acc train: 0.8593750 | Acc validation: 0.7560976
# Epoch: 159 | Cost: 0.5050158 | Acc train: 0.8437500 | Acc validation: 0.7560976
# Epoch: 160 | Cost: 0.5600393 | Acc train: 0.7656250 | Acc validation: 0.7804878
# Epoch: 161 | Cost: 0.5073864 | Acc train: 0.8125000 | Acc validation: 0.7804878
# Epoch: 162 | Cost: 0.5188724 | Acc train: 0.7968750 | Acc validation: 0.7804878
# Epoch: 163 | Cost: 0.5170504 | Acc train: 0.7187500 | Acc validation: 0.7804878
# Epoch: 164 | Cost: 0.5599130 | Acc train: 0.6718750 | Acc validation: 0.7804878
# Epoch: 165 | Cost: 0.5475903 | Acc train: 0.7500000 | Acc validation: 0.8048780
# Epoch: 166 | Cost: 0.4798837 | Acc train: 0.8750000 | Acc validation: 0.8048780
# Epoch: 167 | Cost: 0.5211908 | Acc train: 0.7968750 | Acc validation: 0.7804878
# Epoch: 168 | Cost: 0.5620233 | Acc train: 0.7343750 | Acc validation: 0.8048780
# Epoch: 169 | Cost: 0.4512122 | Acc train: 0.9218750 | Acc validation: 0.8048780
# Epoch: 170 | Cost: 0.5458299 | Acc train: 0.7187500 | Acc validation: 0.8780488
# Epoch: 171 | Cost: 0.5264881 | Acc train: 0.7968750 | Acc validation: 0.9268293
# Epoch: 172 | Cost: 0.5420877 | Acc train: 0.7968750 | Acc validation: 0.8536585
# Epoch: 173 | Cost: 0.5854024 | Acc train: 0.6562500 | Acc validation: 0.8536585
# Epoch: 174 | Cost: 0.5736792 | Acc train: 0.6875000 | Acc validation: 0.8536585
# Epoch: 175 | Cost: 0.5219203 | Acc train: 0.7031250 | Acc validation: 0.8536585
# Epoch: 176 | Cost: 0.5624068 | Acc train: 0.7343750 | Acc validation: 0.9268293
# Epoch: 177 | Cost: 0.5376901 | Acc train: 0.7812500 | Acc validation: 0.8780488
# Epoch: 178 | Cost: 0.5301801 | Acc train: 0.7656250 | Acc validation: 0.8780488
# Epoch: 179 | Cost: 0.5770146 | Acc train: 0.6875000 | Acc validation: 0.8048780
# Epoch: 180 | Cost: 0.5260042 | Acc train: 0.7656250 | Acc validation: 0.8292683
# Epoch: 181 | Cost: 0.5773204 | Acc train: 0.7656250 | Acc validation: 0.8048780
# Epoch: 182 | Cost: 0.5667294 | Acc train: 0.7968750 | Acc validation: 0.8048780
# Epoch: 183 | Cost: 0.5328666 | Acc train: 0.7812500 | Acc validation: 0.7804878
# Epoch: 184 | Cost: 0.5379293 | Acc train: 0.8750000 | Acc validation: 0.8048780
# Epoch: 185 | Cost: 0.5293283 | Acc train: 0.7812500 | Acc validation: 0.8048780
# Epoch: 186 | Cost: 0.5796805 | Acc train: 0.6562500 | Acc validation: 0.8536585
# Epoch: 187 | Cost: 0.5514796 | Acc train: 0.7812500 | Acc validation: 0.8536585
# Epoch: 188 | Cost: 0.5814564 | Acc train: 0.7500000 | Acc validation: 0.8536585
# Epoch: 189 | Cost: 0.5422994 | Acc train: 0.7187500 | Acc validation: 0.8780488
# Epoch: 190 | Cost: 0.5108657 | Acc train: 0.7656250 | Acc validation: 0.8780488
# Epoch: 191 | Cost: 0.5297076 | Acc train: 0.7656250 | Acc validation: 0.8536585
# Epoch: 192 | Cost: 0.5191165 | Acc train: 0.7500000 | Acc validation: 0.9024390
# Epoch: 193 | Cost: 0.5213856 | Acc train: 0.7500000 | Acc validation: 0.8780488
# Epoch: 194 | Cost: 0.5351123 | Acc train: 0.7968750 | Acc validation: 0.8536585
# Epoch: 195 | Cost: 0.4966983 | Acc train: 0.8125000 | Acc validation: 0.8292683
# Epoch: 196 | Cost: 0.5311488 | Acc train: 0.7968750 | Acc validation: 0.7804878
# Epoch: 197 | Cost: 0.5125139 | Acc train: 0.8437500 | Acc validation: 0.7804878
# Epoch: 198 | Cost: 0.5488561 | Acc train: 0.7812500 | Acc validation: 0.7560976
# Epoch: 199 | Cost: 0.5376433 | Acc train: 0.7968750 | Acc validation: 0.7804878
# Epoch: 200 | Cost: 0.5607298 | Acc train: 0.7500000 | Acc validation: 0.7804878
# Epoch: 201 | Cost: 0.5281961 | Acc train: 0.7812500 | Acc validation: 0.8048780
# Epoch: 202 | Cost: 0.5525338 | Acc train: 0.7500000 | Acc validation: 0.7804878
# Epoch: 203 | Cost: 0.5154436 | Acc train: 0.8593750 | Acc validation: 0.7804878
# Epoch: 204 | Cost: 0.5256422 | Acc train: 0.8593750 | Acc validation: 0.7804878
# Epoch: 205 | Cost: 0.4958061 | Acc train: 0.8750000 | Acc validation: 0.7560976
# Epoch: 206 | Cost: 0.5324418 | Acc train: 0.7812500 | Acc validation: 0.7560976
# Epoch: 207 | Cost: 0.5423346 | Acc train: 0.8125000 | Acc validation: 0.7804878
# Epoch: 208 | Cost: 0.5979404 | Acc train: 0.6406250 | Acc validation: 0.8780488
# Epoch: 209 | Cost: 0.5558095 | Acc train: 0.7343750 | Acc validation: 0.8292683
# Epoch: 210 | Cost: 0.5680547 | Acc train: 0.7343750 | Acc validation: 0.8536585
# Epoch: 211 | Cost: 0.5735603 | Acc train: 0.8281250 | Acc validation: 0.8780488
# Epoch: 212 | Cost: 0.5121289 | Acc train: 0.8593750 | Acc validation: 0.9024390
# Epoch: 213 | Cost: 0.5118757 | Acc train: 0.7343750 | Acc validation: 0.8780488
# Epoch: 214 | Cost: 0.5027351 | Acc train: 0.8281250 | Acc validation: 0.8780488
# Epoch: 215 | Cost: 0.5190064 | Acc train: 0.7656250 | Acc validation: 0.9024390
# Epoch: 216 | Cost: 0.5082433 | Acc train: 0.7812500 | Acc validation: 0.8292683
# Epoch: 217 | Cost: 0.5168802 | Acc train: 0.8593750 | Acc validation: 0.8780488
# Epoch: 218 | Cost: 0.5285590 | Acc train: 0.7812500 | Acc validation: 0.8536585
# Epoch: 219 | Cost: 0.5538914 | Acc train: 0.7500000 | Acc validation: 0.8292683
# Epoch: 220 | Cost: 0.5371081 | Acc train: 0.7343750 | Acc validation: 0.8048780
# Epoch: 221 | Cost: 0.5547600 | Acc train: 0.7031250 | Acc validation: 0.8048780
# Epoch: 222 | Cost: 0.5581888 | Acc train: 0.7500000 | Acc validation: 0.8292683
# Epoch: 223 | Cost: 0.5695546 | Acc train: 0.7656250 | Acc validation: 0.8536585
# Epoch: 224 | Cost: 0.5328880 | Acc train: 0.7968750 | Acc validation: 0.8536585
# Epoch: 225 | Cost: 0.4991638 | Acc train: 0.8593750 | Acc validation: 0.8536585
# Epoch: 226 | Cost: 0.5469205 | Acc train: 0.7343750 | Acc validation: 0.8536585
# Epoch: 227 | Cost: 0.5103375 | Acc train: 0.8281250 | Acc validation: 0.8292683
# Epoch: 228 | Cost: 0.5890152 | Acc train: 0.7031250 | Acc validation: 0.8536585
# Epoch: 229 | Cost: 0.5027156 | Acc train: 0.7656250 | Acc validation: 0.8780488
# Epoch: 230 | Cost: 0.5263509 | Acc train: 0.8125000 | Acc validation: 0.8292683
# Epoch: 231 | Cost: 0.4875090 | Acc train: 0.8281250 | Acc validation: 0.8292683
# Epoch: 232 | Cost: 0.5504460 | Acc train: 0.7812500 | Acc validation: 0.8292683
# Epoch: 233 | Cost: 0.5369270 | Acc train: 0.7968750 | Acc validation: 0.8292683
# Epoch: 234 | Cost: 0.5698314 | Acc train: 0.7500000 | Acc validation: 0.8292683
# Epoch: 235 | Cost: 0.5437060 | Acc train: 0.7812500 | Acc validation: 0.8292683
# Epoch: 236 | Cost: 0.4986693 | Acc train: 0.9062500 | Acc validation: 0.8292683
# Epoch: 237 | Cost: 0.5502767 | Acc train: 0.7968750 | Acc validation: 0.7804878
# Epoch: 238 | Cost: 0.5541867 | Acc train: 0.7343750 | Acc validation: 0.7804878
# Epoch: 239 | Cost: 0.5504288 | Acc train: 0.7968750 | Acc validation: 0.7804878
# Epoch: 240 | Cost: 0.5353362 | Acc train: 0.7968750 | Acc validation: 0.7804878
# Epoch: 241 | Cost: 0.4990924 | Acc train: 0.8750000 | Acc validation: 0.7804878
# Epoch: 242 | Cost: 0.5195091 | Acc train: 0.8281250 | Acc validation: 0.8292683
# Epoch: 243 | Cost: 0.5203676 | Acc train: 0.7968750 | Acc validation: 0.8536585
# Epoch: 244 | Cost: 0.5382211 | Acc train: 0.7656250 | Acc validation: 0.8048780
# Epoch: 245 | Cost: 0.5601562 | Acc train: 0.7031250 | Acc validation: 0.7804878
# Epoch: 246 | Cost: 0.5344609 | Acc train: 0.7656250 | Acc validation: 0.7560976
# Epoch: 247 | Cost: 0.5396490 | Acc train: 0.7343750 | Acc validation: 0.7317073
# Epoch: 248 | Cost: 0.4964270 | Acc train: 0.8593750 | Acc validation: 0.7560976
# Epoch: 249 | Cost: 0.5685187 | Acc train: 0.7343750 | Acc validation: 0.6829268
# Epoch: 250 | Cost: 0.5660072 | Acc train: 0.7656250 | Acc validation: 0.7317073
# Epoch: 251 | Cost: 0.5783138 | Acc train: 0.6875000 | Acc validation: 0.7560976
# Epoch: 252 | Cost: 0.5154489 | Acc train: 0.8281250 | Acc validation: 0.7804878
# Epoch: 253 | Cost: 0.4973950 | Acc train: 0.8593750 | Acc validation: 0.8048780
# Epoch: 254 | Cost: 0.4998034 | Acc train: 0.7968750 | Acc validation: 0.8292683
# Epoch: 255 | Cost: 0.5020705 | Acc train: 0.7968750 | Acc validation: 0.8536585
# Epoch: 256 | Cost: 0.5400592 | Acc train: 0.7968750 | Acc validation: 0.8292683
# Epoch: 257 | Cost: 0.5140844 | Acc train: 0.8281250 | Acc validation: 0.8292683
# Epoch: 258 | Cost: 0.4894722 | Acc train: 0.8125000 | Acc validation: 0.8536585
# Epoch: 259 | Cost: 0.5464227 | Acc train: 0.7500000 | Acc validation: 0.8536585
# Epoch: 260 | Cost: 0.5129259 | Acc train: 0.7968750 | Acc validation: 0.8780488
# Epoch: 261 | Cost: 0.5335003 | Acc train: 0.7812500 | Acc validation: 0.8536585
# Epoch: 262 | Cost: 0.5265335 | Acc train: 0.6718750 | Acc validation: 0.8536585
# Epoch: 263 | Cost: 0.4761375 | Acc train: 0.8281250 | Acc validation: 0.8292683
# Epoch: 264 | Cost: 0.4958963 | Acc train: 0.7656250 | Acc validation: 0.8536585
# Epoch: 265 | Cost: 0.5791649 | Acc train: 0.7187500 | Acc validation: 0.8536585
# Epoch: 266 | Cost: 0.5820989 | Acc train: 0.6718750 | Acc validation: 0.8780488
# Epoch: 267 | Cost: 0.4562080 | Acc train: 0.8281250 | Acc validation: 0.8536585
# Epoch: 268 | Cost: 0.5356075 | Acc train: 0.8125000 | Acc validation: 0.8292683
# Epoch: 269 | Cost: 0.5337201 | Acc train: 0.8125000 | Acc validation: 0.8292683
# Epoch: 270 | Cost: 0.4910114 | Acc train: 0.8593750 | Acc validation: 0.8048780
# Epoch: 271 | Cost: 0.5378820 | Acc train: 0.7656250 | Acc validation: 0.8292683
# Epoch: 272 | Cost: 0.4690208 | Acc train: 0.8750000 | Acc validation: 0.8536585
# Epoch: 273 | Cost: 0.5830261 | Acc train: 0.7656250 | Acc validation: 0.8536585
# Epoch: 274 | Cost: 0.5678637 | Acc train: 0.6875000 | Acc validation: 0.8536585
# Epoch: 275 | Cost: 0.5025414 | Acc train: 0.8125000 | Acc validation: 0.8536585
# Epoch: 276 | Cost: 0.5631635 | Acc train: 0.7031250 | Acc validation: 0.8536585
# Epoch: 277 | Cost: 0.5141392 | Acc train: 0.8593750 | Acc validation: 0.8292683
# Epoch: 278 | Cost: 0.5185468 | Acc train: 0.7968750 | Acc validation: 0.8292683
# Epoch: 279 | Cost: 0.5699419 | Acc train: 0.7187500 | Acc validation: 0.8048780
# Epoch: 280 | Cost: 0.5064597 | Acc train: 0.8125000 | Acc validation: 0.8048780
# Epoch: 281 | Cost: 0.5626045 | Acc train: 0.7343750 | Acc validation: 0.8048780
# Epoch: 282 | Cost: 0.6049890 | Acc train: 0.6718750 | Acc validation: 0.7804878
# Epoch: 283 | Cost: 0.5122227 | Acc train: 0.8125000 | Acc validation: 0.8048780
# Epoch: 284 | Cost: 0.5232505 | Acc train: 0.8437500 | Acc validation: 0.8048780
# Epoch: 285 | Cost: 0.5137014 | Acc train: 0.8437500 | Acc validation: 0.8048780
# Epoch: 286 | Cost: 0.4925227 | Acc train: 0.8750000 | Acc validation: 0.8048780
# Epoch: 287 | Cost: 0.5114919 | Acc train: 0.8125000 | Acc validation: 0.8048780
# Epoch: 288 | Cost: 0.4895801 | Acc train: 0.9218750 | Acc validation: 0.9024390
# Epoch: 289 | Cost: 0.5303183 | Acc train: 0.7656250 | Acc validation: 0.8780488
# Epoch: 290 | Cost: 0.5063007 | Acc train: 0.7812500 | Acc validation: 0.8536585
# Epoch: 291 | Cost: 0.5768285 | Acc train: 0.7187500 | Acc validation: 0.8536585
# Epoch: 292 | Cost: 0.5078028 | Acc train: 0.7500000 | Acc validation: 0.8536585
# Epoch: 293 | Cost: 0.5498381 | Acc train: 0.8125000 | Acc validation: 0.8780488
# Epoch: 294 | Cost: 0.5184806 | Acc train: 0.8437500 | Acc validation: 0.8536585
# Epoch: 295 | Cost: 0.5123784 | Acc train: 0.8593750 | Acc validation: 0.8048780
# Epoch: 296 | Cost: 0.5495693 | Acc train: 0.7968750 | Acc validation: 0.8048780
# Epoch: 297 | Cost: 0.4809087 | Acc train: 0.8593750 | Acc validation: 0.8048780
# Epoch: 298 | Cost: 0.5960297 | Acc train: 0.6406250 | Acc validation: 0.7804878
# Epoch: 299 | Cost: 0.5877487 | Acc train: 0.6718750 | Acc validation: 0.7560976
# Epoch: 300 | Cost: 0.5107200 | Acc train: 0.7968750 | Acc validation: 0.7560976
# [[ 0.2198563 ]
#  [ 0.59170488]
#  [ 0.06888765]
#  [ 0.93316404]
#  [-0.3455344 ]
#  [-1.12697682]
#  [-0.05007563]
#  [ 0.06103623]
#  [-0.27179289]
#  [ 0.71125774]
#  [ 0.08785704]
#  [-2.49522919]
#  [-0.01989585]
#  [ 0.16197605]
#  [-0.12698632]
#  [ 0.65559437]
#  [-0.9639345 ]
#  [-0.50518872]
#  [ 0.43362234]
#  [ 0.36522319]
#  [ 0.05046076]
#  [ 0.57903424]
#  [ 0.40054458]
#  [ 2.57684449]
#  [ 1.21482832]
#  [ 1.01836236]
#  [ 2.30640852]
#  [-0.1352778 ]
#  [ 0.1006364 ]
#  [-0.24985649]
#  [-1.19883352]
#  [ 1.54397546]]
# --- %hr --- % 0.8310679860247506

# %%
from Modules.Utils import plot_metrics_accuracy_and_cost
plot_metrics_accuracy_and_cost(val_accuracies,costs)

# %% [markdown]
# In the cell below, we evaluate the model using different sets of parameters. We use the parameters corresponding to the minimum cost function value, the maximum validation set accuracy, and the final parameters returned at the end of the training process.
# Note that in binary classification, recall of the positive class is also known as “sensitivity”; recall of the negative class is “specificity”.

# %%
from Modules.metrices import accuracy
# Find the parameters that give the minimum cost
params_min_costs = all_params[np.argmin(costs)]
test_accuracy_min_costs = accuracy(params_min_costs, X_test, Y_test, circuit_peps)

# Find the parameters that give the maximum validation accuracy
params_max_val_accuracy = all_params[np.argmax(val_accuracies)]
test_accuracy_max = accuracy(params_max_val_accuracy, X_test, Y_test, circuit_peps)

# Calculate test accuracy for the final parameters after the last epoch
test_accuracy_final = accuracy(all_params[-1], X_test, Y_test, circuit_peps)

print(f"Test Accuracy with params giving minimum cost: {test_accuracy_min_costs:.4f}")
print(f"Test Accuracy with params giving maximum validation accuracy: {test_accuracy_max:.4f}")
print(f"Test Accuracy with final parameters: {test_accuracy_final:.4f}")
# Out:
# Test Accuracy with params giving minimum cost: 0.7750
# Test Accuracy with params giving maximum validation accuracy: 0.7500
# Test Accuracy with final parameters: 0.7125

# %% [markdown]
# We take params for minimum cost function value. This params is saved as '02_Peps_binary_Exp1.txt' in experiment output.

# %%
from Modules.metrices import accuracy
test_accuracy_min_costs = accuracy(params_min_costs, X_test, Y_test, circuit_peps)
print(f"Test Accuracy with params giving minimum cost: {test_accuracy_min_costs:.4f}")
from Modules.metrices import show_all_metrics

show_all_metrics(params_min_costs, X_test, Y_test, circuit_peps)
# Out:
# Test Accuracy with params giving minimum cost: 0.7750
# Accuracy: 0.7750 | Precision: 0.8125 | Recall: 0.6842 | F1 Score: 0.7429 | AUC-ROC: 0.7707 | Balanced Accuracy: 0.7707
#               precision    recall  f1-score   support
#
#      class 0       0.75      0.86      0.80        42
#      class 1       0.81      0.68      0.74        38
#
#     accuracy                           0.78        80
#    macro avg       0.78      0.77      0.77        80
# weighted avg       0.78      0.78      0.77        80

# %% [markdown]
# <a id="4"></a> <br>
# ### Experiment 2 - 2 classes
# In this section, we perform the training process of the above model. Below, we see the cross entropy cost function. We use the following hyperparameters for training:
# *`qml.AdamOptimizer(stepsize=0.1)`
# * `batch_size = 128`
# * `num_epoch = 300`

# %%
from Modules.training import train_model
import time
# training the circuit parameters
from pennylane import numpy as np
params = np.random.random(size=[32, 1], requires_grad=True)
optimizer = qml.AdamOptimizer(stepsize=0.1)
batch_size = 128
num_epoch = 300

start_time = time.time()
all_params, train_accuracies, val_accuracies, costs = train_model(X_train, Y_train, X_val, Y_val, params, optimizer, circuit_peps, 2, num_epoch, batch_size)
print("--- %hr --- %", (time.time() - start_time)/3600)
# Out:
# Epoch: 1 | Cost: 0.6936306 | Acc train: 0.5703125 | Acc validation: 0.4634146
# Epoch: 2 | Cost: 0.6651585 | Acc train: 0.6328125 | Acc validation: 0.5853659
# Epoch: 3 | Cost: 0.6737893 | Acc train: 0.5859375 | Acc validation: 0.5853659
# Epoch: 4 | Cost: 0.6388936 | Acc train: 0.6718750 | Acc validation: 0.6097561
# Epoch: 5 | Cost: 0.6338777 | Acc train: 0.6796875 | Acc validation: 0.5609756
# Epoch: 6 | Cost: 0.6411513 | Acc train: 0.6562500 | Acc validation: 0.6829268
# Epoch: 7 | Cost: 0.6153372 | Acc train: 0.7187500 | Acc validation: 0.6585366
# Epoch: 8 | Cost: 0.6449714 | Acc train: 0.6953125 | Acc validation: 0.7073171
# Epoch: 9 | Cost: 0.6062805 | Acc train: 0.7031250 | Acc validation: 0.6585366
# Epoch: 10 | Cost: 0.5930689 | Acc train: 0.7500000 | Acc validation: 0.6829268
# Epoch: 11 | Cost: 0.5990798 | Acc train: 0.7500000 | Acc validation: 0.7073171
# Epoch: 12 | Cost: 0.5772675 | Acc train: 0.8046875 | Acc validation: 0.7317073
# Epoch: 13 | Cost: 0.5770866 | Acc train: 0.7812500 | Acc validation: 0.8048780
# Epoch: 14 | Cost: 0.5728038 | Acc train: 0.7500000 | Acc validation: 0.8048780
# Epoch: 15 | Cost: 0.5704804 | Acc train: 0.7421875 | Acc validation: 0.8292683
# Epoch: 16 | Cost: 0.5460918 | Acc train: 0.7656250 | Acc validation: 0.8292683
# Epoch: 17 | Cost: 0.6113260 | Acc train: 0.7031250 | Acc validation: 0.8292683
# Epoch: 18 | Cost: 0.6002248 | Acc train: 0.6718750 | Acc validation: 0.8048780
# Epoch: 19 | Cost: 0.5810265 | Acc train: 0.7578125 | Acc validation: 0.8048780
# Epoch: 20 | Cost: 0.5879306 | Acc train: 0.7187500 | Acc validation: 0.8048780
# Epoch: 21 | Cost: 0.5669209 | Acc train: 0.8125000 | Acc validation: 0.8292683
# Epoch: 22 | Cost: 0.5626598 | Acc train: 0.8046875 | Acc validation: 0.8292683
# Epoch: 23 | Cost: 0.5515552 | Acc train: 0.7656250 | Acc validation: 0.8292683
# Epoch: 24 | Cost: 0.5504806 | Acc train: 0.8437500 | Acc validation: 0.8292683
# Epoch: 25 | Cost: 0.5196110 | Acc train: 0.8359375 | Acc validation: 0.8536585
# Epoch: 26 | Cost: 0.5168636 | Acc train: 0.8359375 | Acc validation: 0.8292683
# Epoch: 27 | Cost: 0.5558440 | Acc train: 0.7968750 | Acc validation: 0.8292683
# Epoch: 28 | Cost: 0.5321501 | Acc train: 0.8359375 | Acc validation: 0.8536585
# Epoch: 29 | Cost: 0.6000021 | Acc train: 0.6796875 | Acc validation: 0.8292683
# Epoch: 30 | Cost: 0.5723387 | Acc train: 0.7343750 | Acc validation: 0.8048780
# Epoch: 31 | Cost: 0.5584091 | Acc train: 0.7890625 | Acc validation: 0.8048780
# Epoch: 32 | Cost: 0.5333623 | Acc train: 0.7890625 | Acc validation: 0.7804878
# Epoch: 33 | Cost: 0.5180969 | Acc train: 0.7890625 | Acc validation: 0.8048780
# Epoch: 34 | Cost: 0.4992141 | Acc train: 0.8593750 | Acc validation: 0.8292683
# Epoch: 35 | Cost: 0.5668070 | Acc train: 0.7500000 | Acc validation: 0.8536585
# Epoch: 36 | Cost: 0.5346626 | Acc train: 0.7968750 | Acc validation: 0.8536585
# Epoch: 37 | Cost: 0.5169418 | Acc train: 0.8125000 | Acc validation: 0.8048780
# Epoch: 38 | Cost: 0.5694046 | Acc train: 0.7187500 | Acc validation: 0.7560976
# Epoch: 39 | Cost: 0.5735465 | Acc train: 0.6875000 | Acc validation: 0.7560976
# Epoch: 40 | Cost: 0.5157123 | Acc train: 0.7968750 | Acc validation: 0.7804878
# Epoch: 41 | Cost: 0.5317589 | Acc train: 0.7734375 | Acc validation: 0.7804878
# Epoch: 42 | Cost: 0.5728860 | Acc train: 0.7343750 | Acc validation: 0.8292683
# Epoch: 43 | Cost: 0.5471106 | Acc train: 0.7578125 | Acc validation: 0.8536585
# Epoch: 44 | Cost: 0.5337464 | Acc train: 0.7812500 | Acc validation: 0.8048780
# Epoch: 45 | Cost: 0.5509664 | Acc train: 0.7421875 | Acc validation: 0.8292683
# Epoch: 46 | Cost: 0.5193973 | Acc train: 0.8125000 | Acc validation: 0.8048780
# Epoch: 47 | Cost: 0.5485527 | Acc train: 0.7578125 | Acc validation: 0.7804878
# Epoch: 48 | Cost: 0.5706966 | Acc train: 0.7578125 | Acc validation: 0.8048780
# Epoch: 49 | Cost: 0.5124230 | Acc train: 0.7890625 | Acc validation: 0.7804878
# Epoch: 50 | Cost: 0.5377745 | Acc train: 0.8281250 | Acc validation: 0.7804878
# Epoch: 51 | Cost: 0.5537245 | Acc train: 0.7500000 | Acc validation: 0.7804878
# Epoch: 52 | Cost: 0.5130375 | Acc train: 0.8203125 | Acc validation: 0.8048780
# Epoch: 53 | Cost: 0.5598583 | Acc train: 0.7421875 | Acc validation: 0.7804878
# Epoch: 54 | Cost: 0.5482412 | Acc train: 0.7578125 | Acc validation: 0.7560976
# Epoch: 55 | Cost: 0.4866586 | Acc train: 0.8593750 | Acc validation: 0.7804878
# Epoch: 56 | Cost: 0.5454629 | Acc train: 0.7968750 | Acc validation: 0.7804878
# Epoch: 57 | Cost: 0.5418841 | Acc train: 0.7656250 | Acc validation: 0.7317073
# Epoch: 58 | Cost: 0.5432565 | Acc train: 0.7734375 | Acc validation: 0.7317073
# Epoch: 59 | Cost: 0.5408769 | Acc train: 0.7421875 | Acc validation: 0.7560976
# Epoch: 60 | Cost: 0.5102918 | Acc train: 0.8750000 | Acc validation: 0.7560976
# Epoch: 61 | Cost: 0.5031760 | Acc train: 0.8125000 | Acc validation: 0.7560976
# Epoch: 62 | Cost: 0.5059701 | Acc train: 0.8203125 | Acc validation: 0.7560976
# Epoch: 63 | Cost: 0.5488536 | Acc train: 0.7656250 | Acc validation: 0.7804878
# Epoch: 64 | Cost: 0.5489906 | Acc train: 0.7734375 | Acc validation: 0.8048780
# Epoch: 65 | Cost: 0.4898249 | Acc train: 0.8593750 | Acc validation: 0.7804878
# Epoch: 66 | Cost: 0.4758381 | Acc train: 0.8984375 | Acc validation: 0.7804878
# Epoch: 67 | Cost: 0.5144517 | Acc train: 0.8125000 | Acc validation: 0.8048780
# Epoch: 68 | Cost: 0.5661284 | Acc train: 0.7500000 | Acc validation: 0.8048780
# Epoch: 69 | Cost: 0.5095655 | Acc train: 0.8359375 | Acc validation: 0.7560976
# Epoch: 70 | Cost: 0.5212705 | Acc train: 0.7812500 | Acc validation: 0.7560976
# Epoch: 71 | Cost: 0.4910486 | Acc train: 0.8281250 | Acc validation: 0.7560976
# Epoch: 72 | Cost: 0.5304140 | Acc train: 0.7968750 | Acc validation: 0.7560976
# Epoch: 73 | Cost: 0.5149618 | Acc train: 0.7890625 | Acc validation: 0.7560976
# Epoch: 74 | Cost: 0.5098972 | Acc train: 0.8515625 | Acc validation: 0.7560976
# Epoch: 75 | Cost: 0.5615565 | Acc train: 0.7343750 | Acc validation: 0.7560976
# Epoch: 76 | Cost: 0.5480010 | Acc train: 0.7656250 | Acc validation: 0.7317073
# Epoch: 77 | Cost: 0.5067644 | Acc train: 0.8437500 | Acc validation: 0.7560976
# Epoch: 78 | Cost: 0.5483968 | Acc train: 0.7734375 | Acc validation: 0.7317073
# Epoch: 79 | Cost: 0.5174449 | Acc train: 0.8203125 | Acc validation: 0.7317073
# Epoch: 80 | Cost: 0.5453826 | Acc train: 0.7890625 | Acc validation: 0.7804878
# Epoch: 81 | Cost: 0.5551198 | Acc train: 0.7656250 | Acc validation: 0.7804878
# Epoch: 82 | Cost: 0.5059601 | Acc train: 0.8281250 | Acc validation: 0.7804878
# Epoch: 83 | Cost: 0.5458075 | Acc train: 0.7890625 | Acc validation: 0.8048780
# Epoch: 84 | Cost: 0.5122361 | Acc train: 0.7968750 | Acc validation: 0.7804878
# Epoch: 85 | Cost: 0.4953734 | Acc train: 0.8437500 | Acc validation: 0.7560976
# Epoch: 86 | Cost: 0.5431153 | Acc train: 0.7734375 | Acc validation: 0.7560976
# Epoch: 87 | Cost: 0.5753779 | Acc train: 0.7109375 | Acc validation: 0.7073171
# Epoch: 88 | Cost: 0.5319600 | Acc train: 0.8203125 | Acc validation: 0.7560976
# Epoch: 89 | Cost: 0.5051387 | Acc train: 0.8203125 | Acc validation: 0.7560976
# Epoch: 90 | Cost: 0.5005462 | Acc train: 0.8593750 | Acc validation: 0.7317073
# Epoch: 91 | Cost: 0.5436093 | Acc train: 0.7656250 | Acc validation: 0.7317073
# Epoch: 92 | Cost: 0.5044541 | Acc train: 0.8125000 | Acc validation: 0.7317073
# Epoch: 93 | Cost: 0.5605064 | Acc train: 0.7656250 | Acc validation: 0.7560976
# Epoch: 94 | Cost: 0.5355255 | Acc train: 0.7968750 | Acc validation: 0.7560976
# Epoch: 95 | Cost: 0.4957248 | Acc train: 0.8593750 | Acc validation: 0.8048780
# Epoch: 96 | Cost: 0.5167028 | Acc train: 0.8281250 | Acc validation: 0.8292683
# Epoch: 97 | Cost: 0.5588135 | Acc train: 0.7656250 | Acc validation: 0.8292683
# Epoch: 98 | Cost: 0.5360940 | Acc train: 0.8046875 | Acc validation: 0.8292683
# Epoch: 99 | Cost: 0.5485305 | Acc train: 0.7578125 | Acc validation: 0.8292683
# Epoch: 100 | Cost: 0.5182050 | Acc train: 0.7968750 | Acc validation: 0.8048780
# Epoch: 101 | Cost: 0.5481361 | Acc train: 0.8046875 | Acc validation: 0.8048780
# Epoch: 102 | Cost: 0.5150788 | Acc train: 0.8125000 | Acc validation: 0.7804878
# Epoch: 103 | Cost: 0.5343465 | Acc train: 0.8046875 | Acc validation: 0.8048780
# Epoch: 104 | Cost: 0.5401003 | Acc train: 0.7890625 | Acc validation: 0.7560976
# Epoch: 105 | Cost: 0.5533816 | Acc train: 0.7890625 | Acc validation: 0.7804878
# Epoch: 106 | Cost: 0.5312978 | Acc train: 0.8437500 | Acc validation: 0.8048780
# Epoch: 107 | Cost: 0.4948843 | Acc train: 0.8437500 | Acc validation: 0.8048780
# Epoch: 108 | Cost: 0.5423890 | Acc train: 0.7656250 | Acc validation: 0.8048780
# Epoch: 109 | Cost: 0.5344460 | Acc train: 0.7968750 | Acc validation: 0.8048780
# Epoch: 110 | Cost: 0.5371883 | Acc train: 0.8203125 | Acc validation: 0.8048780
# Epoch: 111 | Cost: 0.5164115 | Acc train: 0.7968750 | Acc validation: 0.8048780
# Epoch: 112 | Cost: 0.4728602 | Acc train: 0.8671875 | Acc validation: 0.7804878
# Epoch: 113 | Cost: 0.5296138 | Acc train: 0.7890625 | Acc validation: 0.7804878
# Epoch: 114 | Cost: 0.5202824 | Acc train: 0.8203125 | Acc validation: 0.7804878
# Epoch: 115 | Cost: 0.4800929 | Acc train: 0.8671875 | Acc validation: 0.7317073
# Epoch: 116 | Cost: 0.5301776 | Acc train: 0.7968750 | Acc validation: 0.7073171
# Epoch: 117 | Cost: 0.5309146 | Acc train: 0.8125000 | Acc validation: 0.7073171
# Epoch: 118 | Cost: 0.5004198 | Acc train: 0.7890625 | Acc validation: 0.7317073
# Epoch: 119 | Cost: 0.5043604 | Acc train: 0.8593750 | Acc validation: 0.7317073
# Epoch: 120 | Cost: 0.5446026 | Acc train: 0.7656250 | Acc validation: 0.7560976
# Epoch: 121 | Cost: 0.5556727 | Acc train: 0.6796875 | Acc validation: 0.8048780
# Epoch: 122 | Cost: 0.5504316 | Acc train: 0.7343750 | Acc validation: 0.7804878
# Epoch: 123 | Cost: 0.5087256 | Acc train: 0.8281250 | Acc validation: 0.7804878
# Epoch: 124 | Cost: 0.5333346 | Acc train: 0.7968750 | Acc validation: 0.8048780
# Epoch: 125 | Cost: 0.5339607 | Acc train: 0.7890625 | Acc validation: 0.8048780
# Epoch: 126 | Cost: 0.5244445 | Acc train: 0.8203125 | Acc validation: 0.8048780
# Epoch: 127 | Cost: 0.5062207 | Acc train: 0.8281250 | Acc validation: 0.7804878
# Epoch: 128 | Cost: 0.5605727 | Acc train: 0.7656250 | Acc validation: 0.7560976
# Epoch: 129 | Cost: 0.5048734 | Acc train: 0.8281250 | Acc validation: 0.7317073
# Epoch: 130 | Cost: 0.5160250 | Acc train: 0.8046875 | Acc validation: 0.7317073
# Epoch: 131 | Cost: 0.5042186 | Acc train: 0.7968750 | Acc validation: 0.7560976
# Epoch: 132 | Cost: 0.5182973 | Acc train: 0.8281250 | Acc validation: 0.7560976
# Epoch: 133 | Cost: 0.5292511 | Acc train: 0.7812500 | Acc validation: 0.7560976
# Epoch: 134 | Cost: 0.5169399 | Acc train: 0.7734375 | Acc validation: 0.7804878
# Epoch: 135 | Cost: 0.5477126 | Acc train: 0.7812500 | Acc validation: 0.7804878
# Epoch: 136 | Cost: 0.5065331 | Acc train: 0.8281250 | Acc validation: 0.7804878
# Epoch: 137 | Cost: 0.4798910 | Acc train: 0.8359375 | Acc validation: 0.8048780
# Epoch: 138 | Cost: 0.4909168 | Acc train: 0.8437500 | Acc validation: 0.7560976
# Epoch: 139 | Cost: 0.5038929 | Acc train: 0.8203125 | Acc validation: 0.7804878
# Epoch: 140 | Cost: 0.5256544 | Acc train: 0.8046875 | Acc validation: 0.7560976
# Epoch: 141 | Cost: 0.5341348 | Acc train: 0.7968750 | Acc validation: 0.7560976
# Epoch: 142 | Cost: 0.5830242 | Acc train: 0.7578125 | Acc validation: 0.8048780
# Epoch: 143 | Cost: 0.4979221 | Acc train: 0.8828125 | Acc validation: 0.7804878
# Epoch: 144 | Cost: 0.5554783 | Acc train: 0.7500000 | Acc validation: 0.8048780
# Epoch: 145 | Cost: 0.5130360 | Acc train: 0.7968750 | Acc validation: 0.7560976
# Epoch: 146 | Cost: 0.5088711 | Acc train: 0.8203125 | Acc validation: 0.7560976
# Epoch: 147 | Cost: 0.5261604 | Acc train: 0.7500000 | Acc validation: 0.7560976
# Epoch: 148 | Cost: 0.5151631 | Acc train: 0.8046875 | Acc validation: 0.7804878
# Epoch: 149 | Cost: 0.5040778 | Acc train: 0.7968750 | Acc validation: 0.8048780
# Epoch: 150 | Cost: 0.5134622 | Acc train: 0.7968750 | Acc validation: 0.8048780
# Epoch: 151 | Cost: 0.5286079 | Acc train: 0.8125000 | Acc validation: 0.7804878
# Epoch: 152 | Cost: 0.5202134 | Acc train: 0.7656250 | Acc validation: 0.7804878
# Epoch: 153 | Cost: 0.5412298 | Acc train: 0.7734375 | Acc validation: 0.7560976
# Epoch: 154 | Cost: 0.5669189 | Acc train: 0.7031250 | Acc validation: 0.7804878
# Epoch: 155 | Cost: 0.5318304 | Acc train: 0.8281250 | Acc validation: 0.7804878
# Epoch: 156 | Cost: 0.5030956 | Acc train: 0.8593750 | Acc validation: 0.7804878
# Epoch: 157 | Cost: 0.5331304 | Acc train: 0.7812500 | Acc validation: 0.7317073
# Epoch: 158 | Cost: 0.4911617 | Acc train: 0.8906250 | Acc validation: 0.7804878
# Epoch: 159 | Cost: 0.5186448 | Acc train: 0.8437500 | Acc validation: 0.7804878
# Epoch: 160 | Cost: 0.4916381 | Acc train: 0.8593750 | Acc validation: 0.7560976
# Epoch: 161 | Cost: 0.4863013 | Acc train: 0.8671875 | Acc validation: 0.7560976
# Epoch: 162 | Cost: 0.5406233 | Acc train: 0.7890625 | Acc validation: 0.7560976
# Epoch: 163 | Cost: 0.5348767 | Acc train: 0.7890625 | Acc validation: 0.7804878
# Epoch: 164 | Cost: 0.5159485 | Acc train: 0.8046875 | Acc validation: 0.7804878
# Epoch: 165 | Cost: 0.5018584 | Acc train: 0.8593750 | Acc validation: 0.7317073
# Epoch: 166 | Cost: 0.5398782 | Acc train: 0.7812500 | Acc validation: 0.7560976
# Epoch: 167 | Cost: 0.5498596 | Acc train: 0.7734375 | Acc validation: 0.7317073
# Epoch: 168 | Cost: 0.4963116 | Acc train: 0.7968750 | Acc validation: 0.7317073
# Epoch: 169 | Cost: 0.5320513 | Acc train: 0.7968750 | Acc validation: 0.7317073
# Epoch: 170 | Cost: 0.5214123 | Acc train: 0.8359375 | Acc validation: 0.7317073
# Epoch: 171 | Cost: 0.5265128 | Acc train: 0.8437500 | Acc validation: 0.7317073
# Epoch: 172 | Cost: 0.5407028 | Acc train: 0.7656250 | Acc validation: 0.7804878
# Epoch: 173 | Cost: 0.5261149 | Acc train: 0.8125000 | Acc validation: 0.7804878
# Epoch: 174 | Cost: 0.5400170 | Acc train: 0.7812500 | Acc validation: 0.8048780
# Epoch: 175 | Cost: 0.5427129 | Acc train: 0.7968750 | Acc validation: 0.8048780
# Epoch: 176 | Cost: 0.5187844 | Acc train: 0.8203125 | Acc validation: 0.7804878
# Epoch: 177 | Cost: 0.5447530 | Acc train: 0.7812500 | Acc validation: 0.7804878
# Epoch: 178 | Cost: 0.5445346 | Acc train: 0.7968750 | Acc validation: 0.8048780
# Epoch: 179 | Cost: 0.5407878 | Acc train: 0.7968750 | Acc validation: 0.8048780
# Epoch: 180 | Cost: 0.5306965 | Acc train: 0.8203125 | Acc validation: 0.7804878
# Epoch: 181 | Cost: 0.5518553 | Acc train: 0.7421875 | Acc validation: 0.8292683
# Epoch: 182 | Cost: 0.5286754 | Acc train: 0.8281250 | Acc validation: 0.8292683
# Epoch: 183 | Cost: 0.5232969 | Acc train: 0.7890625 | Acc validation: 0.8292683
# Epoch: 184 | Cost: 0.5330573 | Acc train: 0.7890625 | Acc validation: 0.8292683
# Epoch: 185 | Cost: 0.5232060 | Acc train: 0.8046875 | Acc validation: 0.8048780
# Epoch: 186 | Cost: 0.5164277 | Acc train: 0.8359375 | Acc validation: 0.7804878
# Epoch: 187 | Cost: 0.5259944 | Acc train: 0.8125000 | Acc validation: 0.7317073
# Epoch: 188 | Cost: 0.5234151 | Acc train: 0.8281250 | Acc validation: 0.7317073
# Epoch: 189 | Cost: 0.5250491 | Acc train: 0.7968750 | Acc validation: 0.7560976
# Epoch: 190 | Cost: 0.5393356 | Acc train: 0.7734375 | Acc validation: 0.7804878
# Epoch: 191 | Cost: 0.5072968 | Acc train: 0.8359375 | Acc validation: 0.7804878
# Epoch: 192 | Cost: 0.5062800 | Acc train: 0.8671875 | Acc validation: 0.7560976
# Epoch: 193 | Cost: 0.5430722 | Acc train: 0.7734375 | Acc validation: 0.7560976
# Epoch: 194 | Cost: 0.5152543 | Acc train: 0.7890625 | Acc validation: 0.7560976
# Epoch: 195 | Cost: 0.5405909 | Acc train: 0.7968750 | Acc validation: 0.7560976
# Epoch: 196 | Cost: 0.4900094 | Acc train: 0.8281250 | Acc validation: 0.7560976
# Epoch: 197 | Cost: 0.5170054 | Acc train: 0.8515625 | Acc validation: 0.7560976
# Epoch: 198 | Cost: 0.5268961 | Acc train: 0.8125000 | Acc validation: 0.7317073
# Epoch: 199 | Cost: 0.5183946 | Acc train: 0.8359375 | Acc validation: 0.7560976
# Epoch: 200 | Cost: 0.5296856 | Acc train: 0.7890625 | Acc validation: 0.7560976

# %%
from Modules.Utils import plot_metrics_accuracy_and_cost
plot_metrics_accuracy_and_cost(val_accuracies,costs)

# %%
from Modules.metrices import accuracy
# Find the parameters that give the minimum cost
params_min_costs = all_params[np.argmin(costs)]
test_accuracy_min_costs = accuracy(params_min_costs, X_test, Y_test, circuit_peps)

# Find the parameters that give the maximum validation accuracy
params_max_val_accuracy = all_params[np.argmax(val_accuracies)]
test_accuracy_max = accuracy(params_max_val_accuracy, X_test, Y_test, circuit_peps)

# Calculate test accuracy for the final parameters after the last epoch
test_accuracy_final = accuracy(all_params[-1], X_test, Y_test, circuit_peps)

print(f"Test Accuracy with params giving minimum cost: {test_accuracy_min_costs:.4f}")
print(f"Test Accuracy with params giving maximum validation accuracy: {test_accuracy_max:.4f}")
print(f"Test Accuracy with final parameters: {test_accuracy_final:.4f}")
# Out:
# Test Accuracy with params giving minimum cost: 80%
# Test Accuracy with params giving maximum validation accuracy: 74.35%
# Test Accuracy with final parameters: 77.47%

# %%
from Modules.metrices import accuracy
test_accuracy_min_costs = accuracy(params_min_costs, X_test, Y_test, circuit_peps)
print(f"Test Accuracy with params giving minimum cost: {test_accuracy_min_costs:.4f}")
from Modules.metrices import show_all_metrics

show_all_metrics(params_min_costs, X_test, Y_test, circuit_peps)
